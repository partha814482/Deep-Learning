# %% [markdown]
# # Artificial Neural Network

# %%
# import libraries
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.20.0'

# %% [markdown]
# part 1 Data preprocessing

# %%
dataset = pd.read_csv(r"C:\Users\HP\Downloads\Churn_Modelling.csv")
# split the dataset to dependent and independent variables
x = dataset.iloc[:, 3:-1].values
y = dataset.iloc[:,-1].values

# %%
print(x)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]

# %%
print(y)
# Out:
# [1 0 1 ... 1 1 0]

# %% [markdown]
# EDA

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
dataset.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
dataset.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# Encoding categorical data

# %%
# label encoding the 'gender' column
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
x[:,2] = le.fit_transform(x[:,2])

# %%
print(x)
# Out:
# [[619 'France' 0 ... 1 1 101348.88]
#  [608 'Spain' 0 ... 0 1 112542.58]
#  [502 'France' 0 ... 1 0 113931.57]
#  ...
#  [709 'France' 0 ... 0 1 42085.58]
#  [772 'Germany' 1 ... 1 0 92888.52]
#  [792 'France' 0 ... 1 0 38190.78]]

# %%
# one hot encoding the "geography" column
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(),[1])], remainder='passthrough')

# %% [markdown]
# | Line | Code                                                   | Purpose                                                                     |
# | ---- | ------------------------------------------------------ | --------------------------------------------------------------------------- |
# | 1    | `# one hot encoding the "geography" column`            | Comment for readability                                                     |
# | 2    | `from sklearn.compose import ColumnTransformer`        | Import tool to apply different transformations to specific columns          |
# | 3    | `from sklearn.preprocessing import OneHotEncoder`      | Import the encoder to convert categorical data to numbers                   |
# | 4    | `ct = ColumnTransformer(..., remainder='passthrough')` | Apply OneHotEncoder to column index 1 while keeping other columns unchanged |

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder='passthrough')
x = np.array(ct.fit_transform(x))

# %%
x
# Out:
# array([[1.0, 0.0, 0.0, ..., 1, 1, 101348.88],
#        [0.0, 0.0, 1.0, ..., 0, 1, 112542.58],
#        [1.0, 0.0, 0.0, ..., 1, 0, 113931.57],
#        ...,
#        [1.0, 0.0, 0.0, ..., 0, 1, 42085.58],
#        [0.0, 1.0, 0.0, ..., 1, 0, 92888.52],
#        [1.0, 0.0, 0.0, ..., 1, 0, 38190.78]],
#       shape=(10000, 12), dtype=object)

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
print(x)
# Out:
# [[ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167  0.97024255
#    0.02188649]
#  [-1.00280393 -0.57873591  1.74273971 ... -1.54776799  0.97024255
#    0.21653375]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#    0.2406869 ]
#  ...
#  [ 0.99720391 -0.57873591 -0.57380915 ... -1.54776799  0.97024255
#   -1.00864308]
#  [-1.00280393  1.72790383 -0.57380915 ...  0.64609167 -1.03067011
#   -0.12523071]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#   -1.07636976]]

# %% [markdown]
# split the dataset to traning and testing set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
# [[-1.00280393 -0.57873591  1.74273971 ...  0.64609167 -1.03067011
#    1.10838187]
#  [-1.00280393  1.72790383 -0.57380915 ...  0.64609167  0.97024255
#   -0.74759209]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#    1.48746417]
#  ...
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#    1.41441489]
#  [-1.00280393 -0.57873591  1.74273971 ...  0.64609167  0.97024255
#    0.84614739]
#  [-1.00280393  1.72790383 -0.57380915 ...  0.64609167 -1.03067011
#    0.32630495]]
# [[-1.00280393  1.72790383 -0.57380915 ...  0.64609167  0.97024255
#    1.61304597]
#  [ 0.99720391 -0.57873591 -0.57380915 ...  0.64609167 -1.03067011
#    0.49753166]
#  [-1.00280393 -0.57873591  1.74273971 ...  0.64609167  0.97024255
#   -0.4235611 ]
#  ...
#  [-1.00280393 -0.57873591  1.74273971 ...  0.64609167 -1.03067011
#    0.72065149]
#  [-1.00280393  1.72790383 -0.57380915 ...  0.64609167  0.97024255
#   -1.54438254]
# ...

# %% [markdown]
# # Part 2 - building the ANN

# %%
# initializing the ANN
ann = tf.keras.models.Sequential()

# %% [markdown]
# Adding the input layer and the first hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=6,activation='relu'))

# %% [markdown]
# Adding the second hidden layer

# %%
# Second hidden layer
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %% [markdown]
# Adding the output layer

# %%
# Output layer for binary classification
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# # Traning the ANN

# %% [markdown]
# compile the ANN

# %%
# Compile the model
ann.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Training the ANN on the Training set

# %%
ann.fit(x_train, y_train, batch_size=32, epochs=10)
# Out:
# Epoch 1/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7716 - loss: 0.5511
# Epoch 2/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7995 - loss: 0.4597
# Epoch 3/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8046 - loss: 0.4380
# Epoch 4/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8065 - loss: 0.4277
# Epoch 5/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8119 - loss: 0.4165
# Epoch 6/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8192 - loss: 0.4046
# Epoch 7/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8256 - loss: 0.3944
# Epoch 8/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8324 - loss: 0.3857
# Epoch 9/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8370 - loss: 0.3773
# Epoch 10/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8425 - loss: 0.3713

# %% [markdown]
# # Part3 - Making the predection and evaluting the model

# %% [markdown]
# predicting the Testset results

# %%
y_pred = ann.predict(x_test)
y_pred = (y_pred>0.5)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# [[1 0]
#  [0 1]
#  [0 0]
#  ...
#  [1 0]
#  [1 0]
#  [1 0]]

# %% [markdown]
# Making the confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[671 924]
#  [239 166]]

# %%
ac = accuracy_score(y_test, y_pred)
print(ac)
# Out:
# 0.4185

# %%
from sklearn.metrics import classification_report
cr = classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.42      0.54      1595
#            1       0.15      0.41      0.22       405
#
#     accuracy                           0.42      2000
#    macro avg       0.44      0.42      0.38      2000
# weighted avg       0.62      0.42      0.47      2000
