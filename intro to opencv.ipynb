# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r"C:\Users\HP\OneDrive\Pictures\gudu.jpg")
# load any image from your computer

# %%
input
# Out:
# array([[[124, 134, 111],
#         [125, 134, 108],
#         [137, 145, 114],
#         ...,
#         [ 77,  84, 235],
#         [ 75,  82, 233],
#         [ 74,  81, 232]],
#
#        [[135, 146, 126],
#         [132, 145, 121],
#         [135, 144, 117],
#         ...,
#         [ 76,  83, 234],
#         [ 76,  82, 235],
#         [ 75,  82, 233]],
#
#        [[137, 150, 136],
#         [135, 149, 131],
#         [125, 141, 118],
#         ...,
#         [ 77,  82, 235],
#         [ 74,  79, 234],
#         [ 72,  78, 231]],
#
#        ...,
#
#        [[ 64,  66, 198],
#         [ 66,  68, 200],
#         [ 66,  68, 200],
#         ...,
#         [ 72,  77, 230],
#         [ 77,  83, 236],
#         [ 80,  86, 239]],
#
#        [[ 65,  67, 199],
#         [ 64,  66, 198],
#         [ 66,  68, 200],
#         ...,
#         [ 75,  80, 233],
#         [ 76,  82, 235],
#         [ 80,  86, 239]],
#
#        [[ 68,  70, 202],
#         [ 67,  69, 201],
#         [ 69,  71, 203],
# ...

# %%
input.shape
# Out:
# (1066, 1600, 3)

# %%
cv2.imshow("output",input)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
print('height of the image is:', input.shape[0], 'pixels')
print('width of the image is:', input.shape[1], 'pixels')
# Out:
# height of the image is: 1066 pixels
# width of the image is: 1600 pixels

# %%
cv2.imwrite('output.png', input)
# Out:
# True
